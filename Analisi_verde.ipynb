# %% [markdown]
# # Angiografia a fluorescenza pre impianto per valutare la qualità del graft nel trapianto renale
#
# ___

# %%
import sklearn as sk
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import ttest_1samp, wilcoxon, ttest_ind, mannwhitneyu
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/giacomo.gaglione/Desktop/BRUS/sample_parsed.csv"
                      , sep=';'
                      , encoding='utf-8'
                      , decimal =','
                      , error_bad_lines=False)

# %%
df
# Out:
#         out          pz  indice     m  karpinski  KDPI_perc  KDRI  eta_don  \
# 0   no trap    d'angelo    4.72   NaN        7.0        NaN   NaN      NaN
# 1       dgf       raaka    5.66   NaN        5.0      100.0  2.57     75.0
# 2       dgf        khan    6.19   NaN        NaN       23.0  0.77     38.0
# 3       dgf       aiani    7.36   NaN        5.0       93.0  1.70     71.0
# 4       dgf    lucchini    7.79   NaN        NaN       83.0  1.43     65.0
# 5       egf    d'angelo    8.02  0.77        2.0       93.0  1.70     71.0
# 6       egf      ciullo    8.32  1.06        NaN       20.0  0.75     42.0
# 7       egf     colombo    9.10  1.25        5.0       94.0  1.77     64.0
# 8       egf  pisciotta     9.88  1.06        NaN       77.0  1.31     59.0
# 9       egf     bianchi   12.50  1.46        NaN       72.0  1.23     55.0
# 10      egf   meyanciuc   13.64  1.35        NaN        2.0  0.57     25.0
# 11      egf    palmulli   18.12  2.26        3.0       63.0  1.13     57.0
# 12      egf          hu   19.03  2.55        NaN       72.0  1.23     62.0
# 13      egf    spinelli   19.94  2.33        3.0       95.0  1.80     73.0
#
#     altezza_don  peso_don  ...  Diabete Mellito Trasfusioni Pre_TX  \
# 0           NaN       NaN  ...              NaN                NaN
# 1         173.0      74.0  ...               no                 no
# 2         195.0     106.0  ...               no                 si
# 3         180.0      65.0  ...               no                 si
# 4         180.0      65.0  ...               no                 si
# 5         180.0      65.0  ...               no                 si
# 6         180.0      80.0  ...               si                 si
# 7         170.0     100.0  ...               no                 si
# 8         180.0      88.0  ...               no                 si
# 9         155.0      81.0  ...               no                 no
# 10        180.0      75.0  ...               no                 no
# 11        170.0     100.0  ...               no                 si
# 12        165.0      72.0  ...               no                 no
# 13        175.0      70.0  ...               no                 no
#
#    sim_prec TX extra_renale  Morte_Anossia MancCorr HLA  MancCorr HLA-DR  \
# 0                       NaN            NaN           NaN             NaN
# 1                        no             no           6.0             2.0
# 2                        no             no           4.0             1.0
# 3                        no             no           4.0             1.0
# 4                        no             no           2.0             1.0
# 5                        no             no           5.0             1.0
# 6                        no             no           6.0             2.0
# 7                        no             no           2.0             1.0
# 8                        si             no           6.0             2.0
# 9                        no             no           3.0             1.0
# 10                       no             si           4.0             2.0
# 11                       no             no           5.0             2.0
# 12                       no             no           4.0             1.0
# 13                       no             no           6.0             2.0
#
#     Ischemia Fredda_ore  Perfuzione  ATG  dcd
# 0                   NaN         NaN  NaN  NaN
# 1                  20.0          si   si   si
# 2                  24.0          si   si   si
# 3                  13.2          no   no   no
# 4                  17.0          no   no   no
# 5                  19.2          no   no   no
# 6                  10.0          no   no   no
# 7                  13.5          no   si   no
# 8                  13.0          no   no   no
# 9                   9.5          no   no   no
# 10                 10.5          no   no   no
# 11                 18.0          si   si   si
# 12                  9.8          no   no   no
# 13                 12.0          no   si   no
#
# [14 rows x 34 columns]

# %%
df1 = df.drop(['pz'], axis = 1)
df1
# Out:
#         out  indice     m  karpinski  KDPI_perc  KDRI  eta_don  altezza_don  \
# 0   no trap    4.72   NaN        7.0        NaN   NaN      NaN          NaN
# 1       dgf    5.66   NaN        5.0      100.0  2.57     75.0        173.0
# 2       dgf    6.19   NaN        NaN       23.0  0.77     38.0        195.0
# 3       dgf    7.36   NaN        5.0       93.0  1.70     71.0        180.0
# 4       dgf    7.79   NaN        NaN       83.0  1.43     65.0        180.0
# 5       egf    8.02  0.77        2.0       93.0  1.70     71.0        180.0
# 6       egf    8.32  1.06        NaN       20.0  0.75     42.0        180.0
# 7       egf    9.10  1.25        5.0       94.0  1.77     64.0        170.0
# 8       egf    9.88  1.06        NaN       77.0  1.31     59.0        180.0
# 9       egf   12.50  1.46        NaN       72.0  1.23     55.0        155.0
# 10      egf   13.64  1.35        NaN        2.0  0.57     25.0        180.0
# 11      egf   18.12  2.26        3.0       63.0  1.13     57.0        170.0
# 12      egf   19.03  2.55        NaN       72.0  1.23     62.0        165.0
# 13      egf   19.94  2.33        3.0       95.0  1.80     73.0        175.0
#
#     peso_don  eta_ric  ... Diabete Mellito Trasfusioni Pre_TX  \
# 0        NaN      NaN  ...             NaN                NaN
# 1       74.0     60.0  ...              no                 no
# 2      106.0     48.0  ...              no                 si
# 3       65.0     68.0  ...              no                 si
# 4       65.0     54.0  ...              no                 si
# 5       65.0     70.0  ...              no                 si
# 6       80.0     62.0  ...              si                 si
# 7      100.0     61.0  ...              no                 si
# 8       88.0     34.0  ...              no                 si
# 9       81.0     44.0  ...              no                 no
# 10      75.0     34.0  ...              no                 no
# 11     100.0     62.0  ...              no                 si
# 12      72.0     53.0  ...              no                 no
# 13      70.0     65.0  ...              no                 no
#
#     sim_prec TX extra_renale Morte_Anossia MancCorr HLA  MancCorr HLA-DR  \
# 0                        NaN           NaN           NaN             NaN
# 1                         no            no           6.0             2.0
# 2                         no            no           4.0             1.0
# 3                         no            no           4.0             1.0
# 4                         no            no           2.0             1.0
# 5                         no            no           5.0             1.0
# 6                         no            no           6.0             2.0
# 7                         no            no           2.0             1.0
# 8                         si            no           6.0             2.0
# 9                         no            no           3.0             1.0
# 10                        no            si           4.0             2.0
# 11                        no            no           5.0             2.0
# 12                        no            no           4.0             1.0
# 13                        no            no           6.0             2.0
#
#      Ischemia Fredda_ore  Perfuzione  ATG  dcd
# 0                    NaN         NaN  NaN  NaN
# 1                   20.0          si   si   si
# 2                   24.0          si   si   si
# 3                   13.2          no   no   no
# 4                   17.0          no   no   no
# 5                   19.2          no   no   no
# 6                   10.0          no   no   no
# 7                   13.5          no   si   no
# 8                   13.0          no   no   no
# 9                    9.5          no   no   no
# 10                  10.5          no   no   no
# 11                  18.0          si   si   si
# 12                   9.8          no   no   no
# 13                  12.0          no   si   no
#
# [14 rows x 33 columns]

# %% [markdown]
# ## Statistica Descrittiva

# %% [markdown]
# ### Dataset iniziale (No trapianto + EGF + DGF)
#
#
# ___

# %%
df.describe()
# Out:
#           indice         m  karpinski   KDPI_perc       KDRI    eta_don  \
# count  14.000000  9.000000   7.000000   13.000000  13.000000  13.000000
# mean   10.733571  1.565556   4.285714   68.230769   1.381538  58.230769
# std     5.105771  0.645854   1.704336   32.565713   0.539241  15.023059
# min     4.720000  0.770000   2.000000    2.000000   0.570000  25.000000
# 25%     7.467500  1.060000   3.000000   63.000000   1.130000  55.000000
# 50%     8.710000  1.350000   5.000000   77.000000   1.310000  62.000000
# 75%    13.355000  2.260000   5.000000   93.000000   1.700000  71.000000
# max    19.940000  2.550000   7.000000  100.000000   2.570000  75.000000
#
#        altezza_don    peso_don    eta_ric  crea sierica_don   PiccoPRA  \
# count    13.000000   13.000000  13.000000         13.000000  13.000000
# mean    175.615385   80.076923  55.000000          0.847692   0.769231
# std       9.570253   14.262197  11.937336          0.458224   2.773501
# min     155.000000   65.000000  34.000000          0.450000   0.000000
# 25%     170.000000   70.000000  48.000000          0.570000   0.000000
# 50%     180.000000   75.000000  60.000000          0.790000   0.000000
# 75%     180.000000   88.000000  62.000000          0.930000   0.000000
# max     195.000000  106.000000  70.000000          2.200000  10.000000
#
#        Dialisi_Anni        BMI     Peso_kg  MancCorr HLA   MancCorr HLA-DR  \
# count     13.000000  13.000000   13.000000      13.000000        13.000000
# mean       3.692308  26.589231   76.076923       4.384615         1.461538
# std        1.797434   4.149890   15.876931       1.445595         0.518875
# min        1.000000  20.800000   53.000000       2.000000         1.000000
# 25%        3.000000  23.010000   66.500000       4.000000         1.000000
# 50%        4.000000  27.400000   78.500000       4.000000         1.000000
# 75%        5.000000  29.550000   82.000000       6.000000         2.000000
# max        7.000000  33.600000  115.000000       6.000000         2.000000
#
#         Ischemia Fredda_ore
# count             13.000000
# mean              14.592308
# std                4.614373
# min                9.500000
# 25%               10.500000
# 50%               13.200000
# 75%               18.000000
# max               24.000000

# %% [markdown]
# ### Early Graft Function
#
# ___

# %%
egf = df[df["out"]=="egf"]
egf.describe()
# Out:
#           indice         m  karpinski  KDPI_perc      KDRI    eta_don  \
# count   9.000000  9.000000   4.000000   9.000000  9.000000   9.000000
# mean   13.172222  1.565556   3.250000  65.333333  1.276667  56.444444
# std     4.779890  0.645854   1.258306  33.098338  0.433042  14.917365
# min     8.020000  0.770000   2.000000   2.000000  0.570000  25.000000
# 25%     9.100000  1.060000   2.750000  63.000000  1.130000  55.000000
# 50%    12.500000  1.350000   3.000000  72.000000  1.230000  59.000000
# 75%    18.120000  2.260000   3.500000  93.000000  1.700000  64.000000
# max    19.940000  2.550000   5.000000  95.000000  1.800000  73.000000
#
#        altezza_don    peso_don    eta_ric  crea sierica_don   PiccoPRA  \
# count     9.000000    9.000000   9.000000          9.000000   9.000000
# mean    172.777778   81.222222  53.888889          0.863333   1.111111
# std       8.700255   12.577537  13.485589          0.550000   3.333333
# min     155.000000   65.000000  34.000000          0.450000   0.000000
# 25%     170.000000   72.000000  44.000000          0.570000   0.000000
# 50%     175.000000   80.000000  61.000000          0.640000   0.000000
# 75%     180.000000   88.000000  62.000000          0.930000   0.000000
# max     180.000000  100.000000  70.000000          2.200000  10.000000
#
#        Dialisi_Anni        BMI     Peso_kg  MancCorr HLA   MancCorr HLA-DR  \
# count      9.000000   9.000000    9.000000       9.000000         9.000000
# mean       3.888889  26.666667   76.722222       4.555556         1.555556
# std        1.900292   4.314221   18.105785       1.424001         0.527046
# min        1.000000  20.800000   53.000000       2.000000         1.000000
# 25%        3.000000  23.500000   67.000000       4.000000         1.000000
# 50%        4.000000  27.400000   80.000000       5.000000         2.000000
# 75%        5.000000  28.000000   82.000000       6.000000         2.000000
# max        7.000000  33.600000  115.000000       6.000000         2.000000
#
#         Ischemia Fredda_ore
# count              9.000000
# mean              12.833333
# std                3.573863
# min                9.500000
# 25%               10.000000
# 50%               12.000000
# 75%               13.500000
# max               19.200000

# %% [markdown]
# ### Delayed Graft Function
#
# ___

# %%
dgf = df[df["out"]=="dgf"]
#dgf.to_csv('C:/Users/giacomo.gaglione/Desktop/BRUS/saving_test.csv', index=True)
dgf.describe()
# Out:
#          indice    m  karpinski   KDPI_perc      KDRI    eta_don  altezza_don  \
# count  4.000000  0.0        2.0    4.000000  4.000000   4.000000     4.000000
# mean   6.750000  NaN        5.0   74.750000  1.617500  62.250000   182.000000
# std    0.992539  NaN        0.0   35.198248  0.745537  16.680827     9.273618
# min    5.660000  NaN        5.0   23.000000  0.770000  38.000000   173.000000
# 25%    6.057500  NaN        5.0   68.000000  1.265000  58.250000   178.250000
# 50%    6.775000  NaN        5.0   88.000000  1.565000  68.000000   180.000000
# 75%    7.467500  NaN        5.0   94.750000  1.917500  72.000000   183.750000
# max    7.790000  NaN        5.0  100.000000  2.570000  75.000000   195.000000
#
#          peso_don    eta_ric  crea sierica_don  PiccoPRA  Dialisi_Anni  \
# count    4.000000   4.000000           4.00000       4.0      4.000000
# mean    77.500000  57.500000           0.81250       0.0      3.250000
# std     19.467922   8.544004           0.17557       0.0      1.707825
# min     65.000000  48.000000           0.57000       0.0      1.000000
# 25%     65.000000  52.500000           0.77250       0.0      2.500000
# 50%     69.500000  57.000000           0.84500       0.0      3.500000
# 75%     82.000000  62.000000           0.88500       0.0      4.250000
# max    106.000000  68.000000           0.99000       0.0      5.000000
#
#             BMI    Peso_kg  MancCorr HLA   MancCorr HLA-DR  \
# count   4.00000   4.000000       4.000000             4.00
# mean   26.41500  74.625000       4.000000             1.25
# std     4.38116  11.404495       1.632993             0.50
# min    22.30000  64.500000       2.000000             1.00
# 25%    22.83250  66.000000       3.500000             1.00
# 50%    26.28000  72.500000       4.000000             1.00
# 75%    29.86250  81.125000       4.500000             1.25
# max    30.80000  89.000000       6.000000             2.00
#
#         Ischemia Fredda_ore
# count              4.000000
# mean              18.550000
# std                4.576389
# min               13.200000
# 25%               16.050000
# 50%               18.500000
# 75%               21.000000
# max               24.000000

# %% [markdown]
# ##  Grafici Comparati

# %%
lista = ['indice', 'eta_don', 'peso_don', 'eta_ric', 'KDPI_perc', 'KDRI', 'Dialisi_Anni']
      
for i in lista:    	
    groups = [egf[i], dgf[i]]
    group_labels = ['EGF', 'DGF']

    df = pd.DataFrame(groups, index=group_labels).T

    pd.concat(
        [df.mean().rename('Media'), df.min().rename('Min'), 
         df.max().rename('Max')],
        axis=1).plot.bar()
    
    plt.title(i + ' per EGF e DGF')
    plt.xlabel('Categorie')
    plt.ylabel(i)

# %%
bx = dgf.plot.hist('eta_ric')
sns.pairplot(df.loc[:,df.dtypes == 'float64'])

# %% [markdown]
# ## End Point 1
# ### Mann–Whitney *U* test
# ---

# %% [markdown]
# - Test non parametrico dell'ipotesi nulla
# - P Value < 0.005 ipotesi nulla rigettata

# %%
lista = ['indice', 'eta_don', 'peso_don', 'eta_ric', 'PiccoPRA', 'Dialisi_Anni', 'BMI', 'Peso_kg', 'eta_ric', 'MancCorr HLA-DR']          
for i in lista:    
    dgf_i = dgf[i]
    egf_i = egf[i]   
    u_statistic, pVal = stats.mannwhitneyu(dgf_i, egf_i)            
    print ('\nVariabile:', i ,'\nP value:', pVal, '\nU Statistic:', u_statistic, '\n-------------------------------' )
# Out:
# Variabile: indice
# P value: 0.0034637589886132533
# U Statistic: 0.0
# -------------------------------
#
# Variabile: eta_don
# P value: 0.17693874692179512
# U Statistic: 11.5
# -------------------------------
#
# Variabile: peso_don
# P value: 0.24221859728003842
# U Statistic: 13.0
# -------------------------------
#
# Variabile: eta_ric
# P value: 0.4691667874841462
# U Statistic: 17.0
# -------------------------------
#
# Variabile: PiccoPRA
# P value: 0.30853753872598694
# U Statistic: 16.0
# -------------------------------
#
# Variabile: Dialisi_Anni
# P value: 0.347836162245574
# U Statistic: 15.0
# -------------------------------
#
# Variabile: BMI
# P value: 0.46925144238923566
# U Statistic: 18.0
# -------------------------------
#
# Variabile: Peso_kg
# P value: 0.40835692591565953
# U Statistic: 16.0
# -------------------------------
#
# Variabile: eta_ric
# P value: 0.4691667874841462
# U Statistic: 17.0
# -------------------------------
#
# Variabile: MancCorr HLA-DR
# P value: 0.1864992418067436
# U Statistic: 12.5
# -------------------------------

# %% [markdown]
# ## End Point 2
# ### Grafico Indice - m
# ___

# %%
egf.plot.scatter(x='m'
                 , y='indice'
                 , c='DarkBlue')

# %% [markdown]
# ### Spearman Test
# #### Correlazione tra Indice del Verde e m
#
#  - Test **non parametrico** che misura la correlazione tra variabile indipendente e variabile dipendente.
#  - Valori ammessi da -1 a +1
#  - +1 --> correlazione perfetta.
#  - Se il valore della correlazione è positiva allora al crescere di una variabile crescerà anche la seconda.

# %%
correlation, pVal = stats.spearmanr(egf['indice'], egf['m'])
print('\nRisultati Spearman', '\nCorrelazione:', correlation, '\nPValue:', pVal)
# Out:
# Risultati Spearman
# Correlazione: 0.9372466978064098
# PValue: 0.00019163134226574257

# %% [markdown]
# ### Indice di correlazione di Pearson
# #### Correlazione tra *Indice del Verde* e *m*
#
#  - Indice che esprime il grado di correlazione **lineare** tra due variabili
#  - Valori ammessi da -1 a +1
#  - +1 --> perfetta correlazione lineare positiva.
#  - -1 --> perfetta correlazione lineare negativa.
#  - Se la correlazione è positiva allora al crescere di una variabile crescerà anche la seconda.

# %%
correlation, pVal = stats.pearsonr(egf['indice'], egf['m'])
print('\nRisultati Spearman','\nCorrelazione:', correlation, '\nPValue:', pVal)
# Out:
# Risultati Spearman
# Correlazione: 0.9656147473967367
# PValue: 2.4001099157686744e-05
