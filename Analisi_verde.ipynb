# %% [markdown]
# # Angiografia a fluorescenza pre impianto per valutare la qualità del graft nel trapianto renale
#
# ___

# %%
import sklearn as sk
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import ttest_1samp, wilcoxon, ttest_ind, mannwhitneyu
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/Carlo/Desktop/TESI_ANALISI_DATI/sample_parsed.csv"
                      , sep=';'
                      , encoding='utf-8'
                      , decimal =','
                      , error_bad_lines=False)

# %%
df
# Out:
#         out            pz  indice     m  karpinski  KDPI_perc  KDRI  eta_don  \
# 0   no trap  rene_buttato    4.72   NaN        7.0        NaN   NaN      NaN
# 1       dgf         raaka    5.66   NaN        5.0      100.0  2.57     75.0
# 2       dgf          khan    6.19   NaN        NaN       23.0  0.77     38.0
# 3       dgf         aiani    7.36   NaN        3.0       93.0  1.70     71.0
# 4       dgf      lucchini    7.79   NaN        NaN       83.0  1.43     65.0
# 5       egf      d'angelo    8.02  0.77        2.0       93.0  1.70     71.0
# 6       egf        ciullo    8.32  1.06        NaN       20.0  0.75     42.0
# 7       egf       colombo    9.10  1.25        5.0       94.0  1.77     64.0
# 8       egf    pisciotta     9.88  1.06        NaN       77.0  1.31     59.0
# 9       egf       bianchi   12.50  1.46        NaN       72.0  1.23     55.0
# 10      egf     meyanciuc   13.64  1.35        NaN        2.0  0.57     25.0
# 11      egf      palmulli   18.12  2.26        3.0       63.0  1.13     57.0
# 12      egf            hu   19.03  2.55        NaN       72.0  1.23     62.0
# 13      egf      spinelli   19.94  2.33        3.0       95.0  1.80     73.0
#
#     altezza_don  peso_don  crea_sierica_don  PiccoPRA  Dialisi_Anni    BMI  \
# 0           NaN       NaN               NaN       NaN           NaN    NaN
# 1         173.0      74.0              0.84       0.0           4.0  22.30
# 2         195.0     106.0              0.85       0.0           1.0  29.55
# 3         180.0      65.0              0.57       0.0           3.0  30.80
# 4         180.0      65.0              0.99       0.0           5.0  23.01
# 5         180.0      65.0              0.57       0.0           2.0  28.00
# 6         180.0      80.0              0.79      10.0           4.0  27.80
# 7         170.0     100.0              2.20       0.0           3.0  24.80
# 8         180.0      88.0              0.93       0.0           7.0  22.10
# 9         155.0      81.0              1.14       0.0           6.0  33.60
# 10        180.0      75.0              0.45       0.0           1.0  20.80
# 11        170.0     100.0              0.64       0.0           5.0  27.40
# 12        165.0      72.0              0.45       0.0           3.0  23.50
# 13        175.0      70.0              0.60       0.0           4.0  32.00
#
#     Peso_kg  eta_ric  MancCorrHLA  MancCorrHLA-DR  IschemiaFredda_ore
# 0       NaN      NaN          NaN             NaN                 NaN
# 1      64.5     60.0          6.0             2.0                20.0
# 2      78.5     48.0          4.0             1.0                24.0
# 3      89.0     68.0          4.0             1.0                13.2
# 4      66.5     54.0          2.0             1.0                17.0
# 5      82.0     70.0          5.0             1.0                19.2
# 6      86.0     62.0          6.0             2.0                10.0
# 7      67.5     61.0          2.0             1.0                13.5
# 8      53.0     34.0          6.0             2.0                13.0
# 9     115.0     44.0          3.0             1.0                 9.5
# 10     60.0     34.0          4.0             2.0                10.5
# 11     80.0     62.0          5.0             2.0                18.0
# 12     67.0     53.0          4.0             1.0                 9.8
# 13     80.0     65.0          6.0             2.0                12.0

# %%
df1 = df.drop(['pz'], axis = 1)
df1
# Out:
#         out  indice     m  karpinski  KDPI_perc  KDRI  eta_don  altezza_don  \
# 0   no trap    4.72   NaN        7.0        NaN   NaN      NaN          NaN
# 1       dgf    5.66   NaN        5.0      100.0  2.57     75.0        173.0
# 2       dgf    6.19   NaN        NaN       23.0  0.77     38.0        195.0
# 3       dgf    7.36   NaN        3.0       93.0  1.70     71.0        180.0
# 4       dgf    7.79   NaN        NaN       83.0  1.43     65.0        180.0
# 5       egf    8.02  0.77        2.0       93.0  1.70     71.0        180.0
# 6       egf    8.32  1.06        NaN       20.0  0.75     42.0        180.0
# 7       egf    9.10  1.25        5.0       94.0  1.77     64.0        170.0
# 8       egf    9.88  1.06        NaN       77.0  1.31     59.0        180.0
# 9       egf   12.50  1.46        NaN       72.0  1.23     55.0        155.0
# 10      egf   13.64  1.35        NaN        2.0  0.57     25.0        180.0
# 11      egf   18.12  2.26        3.0       63.0  1.13     57.0        170.0
# 12      egf   19.03  2.55        NaN       72.0  1.23     62.0        165.0
# 13      egf   19.94  2.33        3.0       95.0  1.80     73.0        175.0
#
#     peso_don  crea_sierica_don  PiccoPRA  Dialisi_Anni    BMI  Peso_kg  \
# 0        NaN               NaN       NaN           NaN    NaN      NaN
# 1       74.0              0.84       0.0           4.0  22.30     64.5
# 2      106.0              0.85       0.0           1.0  29.55     78.5
# 3       65.0              0.57       0.0           3.0  30.80     89.0
# 4       65.0              0.99       0.0           5.0  23.01     66.5
# 5       65.0              0.57       0.0           2.0  28.00     82.0
# 6       80.0              0.79      10.0           4.0  27.80     86.0
# 7      100.0              2.20       0.0           3.0  24.80     67.5
# 8       88.0              0.93       0.0           7.0  22.10     53.0
# 9       81.0              1.14       0.0           6.0  33.60    115.0
# 10      75.0              0.45       0.0           1.0  20.80     60.0
# 11     100.0              0.64       0.0           5.0  27.40     80.0
# 12      72.0              0.45       0.0           3.0  23.50     67.0
# 13      70.0              0.60       0.0           4.0  32.00     80.0
#
#     eta_ric  MancCorrHLA  MancCorrHLA-DR  IschemiaFredda_ore
# 0       NaN          NaN             NaN                 NaN
# 1      60.0          6.0             2.0                20.0
# 2      48.0          4.0             1.0                24.0
# 3      68.0          4.0             1.0                13.2
# 4      54.0          2.0             1.0                17.0
# 5      70.0          5.0             1.0                19.2
# 6      62.0          6.0             2.0                10.0
# 7      61.0          2.0             1.0                13.5
# 8      34.0          6.0             2.0                13.0
# 9      44.0          3.0             1.0                 9.5
# 10     34.0          4.0             2.0                10.5
# 11     62.0          5.0             2.0                18.0
# 12     53.0          4.0             1.0                 9.8
# 13     65.0          6.0             2.0                12.0

# %% [markdown]
# ## Statistica Descrittiva

# %% [markdown]
# ### Dataset iniziale (No trapianto + EGF + DGF)
#
#
# ___

# %%
df.describe()
# Out:
#           indice         m  karpinski   KDPI_perc       KDRI    eta_don  \
# count  14.000000  9.000000   7.000000   13.000000  13.000000  13.000000
# mean   10.733571  1.565556   4.000000   68.230769   1.381538  58.230769
# std     5.105771  0.645854   1.732051   32.565713   0.539241  15.023059
# min     4.720000  0.770000   2.000000    2.000000   0.570000  25.000000
# 25%     7.467500  1.060000   3.000000   63.000000   1.130000  55.000000
# 50%     8.710000  1.350000   3.000000   77.000000   1.310000  62.000000
# 75%    13.355000  2.260000   5.000000   93.000000   1.700000  71.000000
# max    19.940000  2.550000   7.000000  100.000000   2.570000  75.000000
#
#        altezza_don    peso_don  crea_sierica_don   PiccoPRA  Dialisi_Anni  \
# count    13.000000   13.000000         13.000000  13.000000     13.000000
# mean    175.615385   80.076923          0.847692   0.769231      3.692308
# std       9.570253   14.262197          0.458224   2.773501      1.797434
# min     155.000000   65.000000          0.450000   0.000000      1.000000
# 25%     170.000000   70.000000          0.570000   0.000000      3.000000
# 50%     180.000000   75.000000          0.790000   0.000000      4.000000
# 75%     180.000000   88.000000          0.930000   0.000000      5.000000
# max     195.000000  106.000000          2.200000  10.000000      7.000000
#
#              BMI     Peso_kg    eta_ric  MancCorrHLA  MancCorrHLA-DR  \
# count  13.000000   13.000000  13.000000    13.000000       13.000000
# mean   26.589231   76.076923  55.000000     4.384615        1.461538
# std     4.149890   15.876931  11.937336     1.445595        0.518875
# min    20.800000   53.000000  34.000000     2.000000        1.000000
# 25%    23.010000   66.500000  48.000000     4.000000        1.000000
# 50%    27.400000   78.500000  60.000000     4.000000        1.000000
# 75%    29.550000   82.000000  62.000000     6.000000        2.000000
# max    33.600000  115.000000  70.000000     6.000000        2.000000
#
#        IschemiaFredda_ore
# count           13.000000
# mean            14.592308
# std              4.614373
# min              9.500000
# 25%             10.500000
# 50%             13.200000
# 75%             18.000000
# max             24.000000

# %% [markdown]
# ### Early Graft Function
#
# ___

# %%
egf = df[df["out"]=="egf"]
egf.describe()
# Out:
#           indice         m  karpinski  KDPI_perc      KDRI    eta_don  \
# count   9.000000  9.000000   4.000000   9.000000  9.000000   9.000000
# mean   13.172222  1.565556   3.250000  65.333333  1.276667  56.444444
# std     4.779890  0.645854   1.258306  33.098338  0.433042  14.917365
# min     8.020000  0.770000   2.000000   2.000000  0.570000  25.000000
# 25%     9.100000  1.060000   2.750000  63.000000  1.130000  55.000000
# 50%    12.500000  1.350000   3.000000  72.000000  1.230000  59.000000
# 75%    18.120000  2.260000   3.500000  93.000000  1.700000  64.000000
# max    19.940000  2.550000   5.000000  95.000000  1.800000  73.000000
#
#        altezza_don    peso_don  crea_sierica_don   PiccoPRA  Dialisi_Anni  \
# count     9.000000    9.000000          9.000000   9.000000      9.000000
# mean    172.777778   81.222222          0.863333   1.111111      3.888889
# std       8.700255   12.577537          0.550000   3.333333      1.900292
# min     155.000000   65.000000          0.450000   0.000000      1.000000
# 25%     170.000000   72.000000          0.570000   0.000000      3.000000
# 50%     175.000000   80.000000          0.640000   0.000000      4.000000
# 75%     180.000000   88.000000          0.930000   0.000000      5.000000
# max     180.000000  100.000000          2.200000  10.000000      7.000000
#
#              BMI     Peso_kg    eta_ric  MancCorrHLA  MancCorrHLA-DR  \
# count   9.000000    9.000000   9.000000     9.000000        9.000000
# mean   26.666667   76.722222  53.888889     4.555556        1.555556
# std     4.314221   18.105785  13.485589     1.424001        0.527046
# min    20.800000   53.000000  34.000000     2.000000        1.000000
# 25%    23.500000   67.000000  44.000000     4.000000        1.000000
# 50%    27.400000   80.000000  61.000000     5.000000        2.000000
# 75%    28.000000   82.000000  62.000000     6.000000        2.000000
# max    33.600000  115.000000  70.000000     6.000000        2.000000
#
#        IschemiaFredda_ore
# count            9.000000
# mean            12.833333
# std              3.573863
# min              9.500000
# 25%             10.000000
# 50%             12.000000
# 75%             13.500000
# max             19.200000

# %% [markdown]
# ### Delayed Graft Function
#
# ___

# %%
dgf = df[df["out"]=="dgf"]
#dgf.to_csv('C:/Users/giacomo.gaglione/Desktop/BRUS/saving_test.csv', index=True)
dgf.describe()
# Out:
#          indice    m  karpinski   KDPI_perc      KDRI    eta_don  altezza_don  \
# count  4.000000  0.0   2.000000    4.000000  4.000000   4.000000     4.000000
# mean   6.750000  NaN   4.000000   74.750000  1.617500  62.250000   182.000000
# std    0.992539  NaN   1.414214   35.198248  0.745537  16.680827     9.273618
# min    5.660000  NaN   3.000000   23.000000  0.770000  38.000000   173.000000
# 25%    6.057500  NaN   3.500000   68.000000  1.265000  58.250000   178.250000
# 50%    6.775000  NaN   4.000000   88.000000  1.565000  68.000000   180.000000
# 75%    7.467500  NaN   4.500000   94.750000  1.917500  72.000000   183.750000
# max    7.790000  NaN   5.000000  100.000000  2.570000  75.000000   195.000000
#
#          peso_don  crea_sierica_don  PiccoPRA  Dialisi_Anni       BMI  \
# count    4.000000           4.00000       4.0      4.000000   4.00000
# mean    77.500000           0.81250       0.0      3.250000  26.41500
# std     19.467922           0.17557       0.0      1.707825   4.38116
# min     65.000000           0.57000       0.0      1.000000  22.30000
# 25%     65.000000           0.77250       0.0      2.500000  22.83250
# 50%     69.500000           0.84500       0.0      3.500000  26.28000
# 75%     82.000000           0.88500       0.0      4.250000  29.86250
# max    106.000000           0.99000       0.0      5.000000  30.80000
#
#          Peso_kg    eta_ric  MancCorrHLA  MancCorrHLA-DR  IschemiaFredda_ore
# count   4.000000   4.000000     4.000000            4.00            4.000000
# mean   74.625000  57.500000     4.000000            1.25           18.550000
# std    11.404495   8.544004     1.632993            0.50            4.576389
# min    64.500000  48.000000     2.000000            1.00           13.200000
# 25%    66.000000  52.500000     3.500000            1.00           16.050000
# 50%    72.500000  57.000000     4.000000            1.00           18.500000
# 75%    81.125000  62.000000     4.500000            1.25           21.000000
# max    89.000000  68.000000     6.000000            2.00           24.000000

# %% [markdown]
# ##  Grafici Comparati

# %%
lista = ['indice', 'eta_don', 'peso_don', 'eta_ric', 'KDPI_perc', 'KDRI', 'Dialisi_Anni']
      
for i in lista:    	
    groups = [egf[i], dgf[i]]
    group_labels = ['EGF', 'DGF']

    df = pd.DataFrame(groups, index=group_labels).T

    pd.concat(
        [df.mean().rename('Media'), df.min().rename('Min'), 
         df.max().rename('Max')],
        axis=1).plot.bar()
    
    plt.title(i + ' per EGF e DGF')
    plt.xlabel('Categorie')
    plt.ylabel(i)

# %%
bx = dgf.plot.hist('eta_ric')
sns.pairplot(df.loc[:,df.dtypes == 'float64'])

# %% [markdown]
# ## End Point 1
# ### Mann–Whitney *U* test
# ---

# %% [markdown]
# - Test non parametrico dell'ipotesi nulla
# - P Value < 0.005 ipotesi nulla rigettata

# %%
lista = ['indice', 'eta_don', 'peso_don', 'eta_ric', 'PiccoPRA', 'Dialisi_Anni', 'BMI', 'Peso_kg', 'eta_ric', 'MancCorrHLA-DR']          
for i in lista:    
    dgf_i = dgf[i]
    egf_i = egf[i]   
    u_statistic, pVal = stats.mannwhitneyu(dgf_i, egf_i)            
    print ('\nVariabile:', i ,'\nP value:', pVal, '\nU Statistic:', u_statistic, '\n-------------------------------' )
# Out:
# Variabile: indice
# P value: 0.0034637589886132533
# U Statistic: 0.0
# -------------------------------
#
# Variabile: eta_don
# P value: 0.17693874692179512
# U Statistic: 11.5
# -------------------------------
#
# Variabile: peso_don
# P value: 0.24221859728003842
# U Statistic: 13.0
# -------------------------------
#
# Variabile: eta_ric
# P value: 0.4691667874841462
# U Statistic: 17.0
# -------------------------------
#
# Variabile: PiccoPRA
# P value: 0.30853753872598694
# U Statistic: 16.0
# -------------------------------
#
# Variabile: Dialisi_Anni
# P value: 0.347836162245574
# U Statistic: 15.0
# -------------------------------
#
# Variabile: BMI
# P value: 0.46925144238923566
# U Statistic: 18.0
# -------------------------------
#
# Variabile: Peso_kg
# P value: 0.40835692591565953
# U Statistic: 16.0
# -------------------------------
#
# Variabile: eta_ric
# P value: 0.4691667874841462
# U Statistic: 17.0
# -------------------------------
#
# Variabile: MancCorrHLA-DR
# P value: 0.1864992418067436
# U Statistic: 12.5
# -------------------------------

# %% [markdown]
# ## End Point 2
# ### Grafico Indice - m
# ___

# %%
egf.plot.scatter(x='m'
                 , y='indice'
                 , c='DarkBlue')

# %% [markdown]
# ### Spearman Test
# #### Correlazione tra Indice del Verde e m
#
#  - Test **non parametrico** che misura la correlazione tra variabile indipendente e variabile dipendente.
#  - Valori ammessi da -1 a +1
#  - +1 --> correlazione perfetta.
#  - Se il valore della correlazione è positiva allora al crescere di una variabile crescerà anche la seconda.

# %%
correlation, pVal = stats.spearmanr(egf['indice'], egf['m'])
print('\nRisultati Spearman', '\nCorrelazione:', correlation, '\nPValue:', pVal)
# Out:
# Risultati Spearman
# Correlazione: 0.9372466978064098
# PValue: 0.00019163134226574257

# %% [markdown]
# ### Indice di correlazione di Pearson
# #### Correlazione tra *Indice del Verde* e *m*
#
#  - Indice che esprime il grado di correlazione **lineare** tra due variabili
#  - Valori ammessi da -1 a +1
#  - +1 --> perfetta correlazione lineare positiva.
#  - -1 --> perfetta correlazione lineare negativa.
#  - Se la correlazione è positiva allora al crescere di una variabile crescerà anche la seconda.

# %%
correlation, pVal = stats.pearsonr(egf['indice'], egf['m'])
print('\nRisultati Pearson','\nCorrelazione:', correlation, '\nPValue:', pVal)
# Out:
# Risultati Pearson
# Correlazione: 0.9656147473967367
# PValue: 2.4001099157686744e-05

# %% [markdown]
# # EndPoint 3A (NO SCARTATI)
#
# - Estraggo dal campione le colonne out indice e karpinski

# %%
end3 = df[['out', 'pz', 'indice','karpinski']]

# %%
end3.head(3)
# Out:
#        out            pz  indice  karpinski
# 0  no trap  rene_buttato    4.72        7.0
# 1      dgf         raaka    5.66        5.0
# 2      dgf          khan    6.19        NaN

# %% [markdown]
# - Elimino i valori mancanti dal campo karpinski 7 in totale, 1 non trapiantato, 2 GDF e 4 EGF

# %%
end3_notnull = end3[end3.karpinski.notnull()]
end3_notnull
# Out:
#         out            pz  indice  karpinski
# 0   no trap  rene_buttato    4.72        7.0
# 1       dgf         raaka    5.66        5.0
# 3       dgf         aiani    7.36        3.0
# 5       egf      d'angelo    8.02        2.0
# 7       egf       colombo    9.10        5.0
# 11      egf      palmulli   18.12        3.0
# 13      egf      spinelli   19.94        3.0

# %% [markdown]
# - Entrambi i test (Spearman (non-lineare) e Pearson (lineare)) suggeriscono una correlazione negativa tra le variabile indice e karpinski.
#
# - Presentano entrambi pValue statisticamente non significativi

# %%
correlation, pVal = stats.spearmanr(end3_notnull['indice'], end3_notnull['karpinski'])
print('\nRisultati Spearman Endpoint 3A:', '\nCorrelazione:', correlation, '\nPValue:', pVal)
# Out:
# Risultati Spearman Endpoint 3:
# Correlazione: -0.5426488617097118
# PValue: 0.2081851760215384

# %% [markdown]
# Il test di Pearson presenta un PValue troppo alto e non si trova significatività statistica rilevante di correlazione lineare tra le variabili indice e karpinski

# %%
correlation, pVal = stats.pearsonr(end3_notnull['indice'], end3_notnull['karpinski'])
print('\nRisultati Pearson EndPoint 3A','\nCorrelazione:', correlation, '\nPValue:', pVal)
# Out:
# Risultati Pearson EndPoint 3
# Correlazione: -0.5148366214227523
# PValue: 0.23705458236443727

# %% [markdown]
# # ENDPOINT 3B
# ## SCARTO IL KARPINSKI DI D'ANGELO e AIANI

# %%
end3_scartati = end3_notnull[end3_notnull["pz"]!="d'angelo"]
end3_scartati = end3_scartati[end3_scartati["pz"]!="aiani"]
end3_scartati
# Out:
#         out            pz  indice  karpinski
# 0   no trap  rene_buttato    4.72        7.0
# 1       dgf         raaka    5.66        5.0
# 7       egf       colombo    9.10        5.0
# 11      egf      palmulli   18.12        3.0
# 13      egf      spinelli   19.94        3.0

# %%
correlation, pVal = stats.spearmanr(end3_scartati['indice'], end3_scartati['karpinski'])
print('\nRisultati Spearman Endpoint 3B:', '\nCorrelazione:', correlation, '\nPValue:', pVal)
# Out:
# Risultati Spearman Endpoint 3B:
# Correlazione: -0.9486832980505138
# PValue: 0.013846832988859059

# %%
correlation, pVal = stats.pearsonr(end3_scartati['indice'], end3_scartati['karpinski'])
print('\nRisultati Pearson EndPoint 3B','\nCorrelazione:', correlation, '\nPValue:', pVal)
# Out:
# Risultati Pearson EndPoint 3B
# Correlazione: -0.9205206419488188
# PValue: 0.02657473126882828

# %% [markdown]
# # ENDPOINT 4
# ## Relazione Indice - KDPI

# %%
end4 = df[df["pz"]!= "rene_buttato"]
end4
# Out:
#     out          pz  indice     m  karpinski  KDPI_perc  KDRI  eta_don  \
# 1   dgf       raaka    5.66   NaN        5.0      100.0  2.57     75.0
# 2   dgf        khan    6.19   NaN        NaN       23.0  0.77     38.0
# 3   dgf       aiani    7.36   NaN        3.0       93.0  1.70     71.0
# 4   dgf    lucchini    7.79   NaN        NaN       83.0  1.43     65.0
# 5   egf    d'angelo    8.02  0.77        2.0       93.0  1.70     71.0
# 6   egf      ciullo    8.32  1.06        NaN       20.0  0.75     42.0
# 7   egf     colombo    9.10  1.25        5.0       94.0  1.77     64.0
# 8   egf  pisciotta     9.88  1.06        NaN       77.0  1.31     59.0
# 9   egf     bianchi   12.50  1.46        NaN       72.0  1.23     55.0
# 10  egf   meyanciuc   13.64  1.35        NaN        2.0  0.57     25.0
# 11  egf    palmulli   18.12  2.26        3.0       63.0  1.13     57.0
# 12  egf          hu   19.03  2.55        NaN       72.0  1.23     62.0
# 13  egf    spinelli   19.94  2.33        3.0       95.0  1.80     73.0
#
#     altezza_don  peso_don  crea_sierica_don  PiccoPRA  Dialisi_Anni    BMI  \
# 1         173.0      74.0              0.84       0.0           4.0  22.30
# 2         195.0     106.0              0.85       0.0           1.0  29.55
# 3         180.0      65.0              0.57       0.0           3.0  30.80
# 4         180.0      65.0              0.99       0.0           5.0  23.01
# 5         180.0      65.0              0.57       0.0           2.0  28.00
# 6         180.0      80.0              0.79      10.0           4.0  27.80
# 7         170.0     100.0              2.20       0.0           3.0  24.80
# 8         180.0      88.0              0.93       0.0           7.0  22.10
# 9         155.0      81.0              1.14       0.0           6.0  33.60
# 10        180.0      75.0              0.45       0.0           1.0  20.80
# 11        170.0     100.0              0.64       0.0           5.0  27.40
# 12        165.0      72.0              0.45       0.0           3.0  23.50
# 13        175.0      70.0              0.60       0.0           4.0  32.00
#
#     Peso_kg  eta_ric  MancCorrHLA  MancCorrHLA-DR  IschemiaFredda_ore
# 1      64.5     60.0          6.0             2.0                20.0
# 2      78.5     48.0          4.0             1.0                24.0
# 3      89.0     68.0          4.0             1.0                13.2
# 4      66.5     54.0          2.0             1.0                17.0
# 5      82.0     70.0          5.0             1.0                19.2
# 6      86.0     62.0          6.0             2.0                10.0
# 7      67.5     61.0          2.0             1.0                13.5
# 8      53.0     34.0          6.0             2.0                13.0
# 9     115.0     44.0          3.0             1.0                 9.5
# 10     60.0     34.0          4.0             2.0                10.5
# 11     80.0     62.0          5.0             2.0                18.0
# 12     67.0     53.0          4.0             1.0                 9.8
# 13     80.0     65.0          6.0             2.0                12.0

# %%
correlation, pVal = stats.spearmanr(end4['indice'], end4['KDPI_perc'])
print('\nRisultati Spearman Endpoint 4:', '\nCorrelazione:', correlation, '\nPValue:', pVal)
# Out:
# Risultati Spearman Endpoint 4:
# Correlazione: -0.21763167980364392
# PValue: 0.4750727787911654

# %% [markdown]
# ## Correlazione: INDICE - KDRI

# %%
correlation, pVal = stats.spearmanr(end4['indice'], end4['KDRI'])
print('\nRisultati Spearman Endpoint 4:', '\nCorrelazione:', correlation, '\nPValue:', pVal)
# Out:
# Risultati Spearman Endpoint 4:
# Correlazione: -0.21763167980364392
# PValue: 0.4750727787911654
